# %% [markdown]
# ## Importing dependencies

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Extracting html content from koimoi

# %%
html_file = requests.get("https://www.koimoi.com/box-office/bollywoods-100-crore-club/").content

# %% [markdown]
# ## Creating a soup object

# %%
soup = BeautifulSoup(html_file, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE doctype html >
#
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <!-- //commented vk 23 may -->
# <!--
# <div class="pageHolder" id="page-background" style="position:relative; top:0px;">
# -->
# <!-- Main Holder Start-->
# <!--
#             <div class="mainHolder">
#             <div class="contentHolder">
#      -->
# <head>
# <title>Bollywood's 100 Crore Club Movies | Koimoi</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="C73B5F107EC533B7F8E60D6FBF73840B" name="msvalidate.01">
# <link href="https://www.koimoi.com/xmlrpc.php" rel="pingback"/>
# <meta content="379203805755441" property="fb:app_id"/>
# <meta content="articlepage" name="atdlayout"/> <!-- JM Twitter Cards by Julien Maury 10.1.0 -->
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %% [markdown]
# ## Extracting Box Office table

# %%
boxoffice = soup.find('table', attrs={"id":"tablepress-8"})

# %%
rows = []
for i in boxoffice.find_all('tr'):
    try:
        rows.append([i.find('td', class_="column-1").get_text(), 
                     i.find('td', class_="column-2").get_text(),
                     i.find('td', class_="column-3").get_text()])
    except:
        pass

# %% [markdown]
# ## Converting the data collected into dataframe

# %%
df = pd.DataFrame(rows, columns=['Movie', 'Days to reach 100 crores', 'Total Collection'])

# %%
df
# Out:
#                           Movie Days to reach 100 crores Total Collection
# 0             Baahubali 2 Hindi                        3           511.30
# 1                Happy New Year                        3           205.00
# 2                       Dhoom 3                        3           280.25
# 3                        Dangal                        3           387.39
# 4                         Sanju                        3           341.22
# 5               Tiger Zinda Hai                        3           339.16
# 6             Bajrangi Bhaijaan                        3           320.34
# 7                           War                        3           317.77
# 8                        Sultan                        3           300.45
# 9          Prem Ratan Dhan Payo                        3           207.40
# 10           Thugs Of Hindostan                        3           145.29
# 11                      Race 3                         3           169.00
# ...
